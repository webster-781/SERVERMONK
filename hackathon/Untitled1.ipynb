# %%
from Untitled import User, Food , db
db.create_all()

# %%
user = User(email="hack@man.com",password="A")

# %%
db.session.add(user)

# %%
db.session.commit()
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-19-a8e4ec8c4c52> in <module>
# ----> 1 db.session.commit()
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/orm/scoping.py in do(self, *args, **kwargs)
#     160 def instrument(name):
#     161     def do(self, *args, **kwargs):
# --> 162         return getattr(self.registry(), name)(*args, **kwargs)
#     163
#     164     return do
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/orm/session.py in commit(self)
#    1034                 raise sa_exc.InvalidRequestError("No transaction is begun.")
#    1035
# -> 1036         self.transaction.commit()
#    1037
#    1038     def prepare(self):
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/orm/session.py in commit(self)
#     499
#     500     def commit(self):
# --> 501         self._assert_active(prepared_ok=True)
# ...

# %%
User.query.get(2)
# Out:
# email: singhayush4499@gmail.com, password: $2b$12$4OxEg3rmAzIZ9JTfpFqcwOwAFQlo/xHa6MzWe4FM.3YzsrGG.68pu,image: #

# %%
food = Food(food_name="milk",user_id = 1,quantity=10.0,food_date=d)
food.getNutrients()

# %%
db.session.add(food)

# %%
Food.query.all()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#
# IntegrityError: UNIQUE constraint failed: user.email
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-11-738b731d0045> in <module>
# ...

# %%
import datetime 
d = datetime.date(2020,2,21)

# %%
db.drop_all()
